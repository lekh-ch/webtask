# %% [markdown]
# <a href="https://colab.research.google.com/github/lekh-ch/webtask/blob/main/Dataanalyst_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ====================================================
# Import Required Libraries
# ====================================================

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

plt.style.use("ggplot")

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows",10)

# %%
# ==========================================
# Load Dataset
# ==========================================

df = pd.read_csv("/content/Amazon.csv")

df.head()
# Out:
#       OrderID   OrderDate  CustomerID   CustomerName ProductID  \
# 0  ORD0000001  2023-01-31  CUST001504  Vihaan Sharma    P00014
# 1  ORD0000002  2023-12-30  CUST000178    Pooja Kumar    P00040
# 2  ORD0000003  2022-05-10  CUST047516    Sneha Singh    P00044
# 3  ORD0000004  2023-07-18  CUST030059   Vihaan Reddy    P00041
# 4  ORD0000005  2023-02-04  CUST048677  Aditya Kapoor    P00029
#
#            ProductName        Category       Brand  Quantity  UnitPrice  \
# 0           Drone Mini           Books   BrightLux         3     106.59
# 1           Microphone  Home & Kitchen  UrbanStyle         1     251.37
# 2  Power Bank 20000mAh        Clothing  UrbanStyle         3      35.03
# 3       Webcam Full HD  Home & Kitchen      Zenith         5      33.58
# 4              T-Shirt        Clothing    KiddoFun         2     515.64
#
#    Discount    Tax  ShippingCost  TotalAmount     PaymentMethod OrderStatus  \
# ...

# %%
print("Rows :",df.shape[0])
print("Columns :",df.shape[1])
# Out:
# Rows : 100000
# Columns : 26

# %%
df.columns
# Out:
# Index(['OrderID', 'OrderDate', 'CustomerID', 'CustomerName', 'ProductID',
#        'ProductName', 'Category', 'Brand', 'Quantity', 'UnitPrice', 'Discount',
#        'Tax', 'ShippingCost', 'TotalAmount', 'PaymentMethod', 'OrderStatus',
#        'City', 'State', 'Country', 'SellerID', 'Year', 'MonthNo', 'Month',
#        'Quarter', 'WeekDay', 'Weekend'],
#       dtype='object')

# %%
df.dtypes
# Out:
# OrderID                 object
# OrderDate       datetime64[ns]
# CustomerID              object
# CustomerName            object
# ProductID               object
#                      ...
# MonthNo                  int32
# Month                   object
# Quarter                  int32
# WeekDay                 object
# Weekend                 object
# Length: 26, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 26 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   OrderID        100000 non-null  object
#  1   OrderDate      100000 non-null  datetime64[ns]
#  2   CustomerID     100000 non-null  object
#  3   CustomerName   100000 non-null  object
#  4   ProductID      100000 non-null  object
#  5   ProductName    100000 non-null  object
#  6   Category       100000 non-null  object
#  7   Brand          100000 non-null  object
#  8   Quantity       100000 non-null  int64
#  9   UnitPrice      100000 non-null  float64
#  10  Discount       100000 non-null  float64
#  11  Tax            100000 non-null  float64
#  12  ShippingCost   100000 non-null  float64
#  13  TotalAmount    100000 non-null  float64
#  14  PaymentMethod  100000 non-null  object
#  15  OrderStatus    100000 non-null  object
#  16  City           100000 non-null  object
# ...

# %%
df.describe()
# Out:
#                         OrderDate       Quantity      UnitPrice  \
# count                      100000  100000.000000  100000.000000
# mean   2022-06-30 23:55:49.440000       3.001400     302.905748
# min           2020-01-01 00:00:00       1.000000       5.000000
# 25%           2021-04-01 00:00:00       2.000000     154.190000
# 50%           2022-07-01 00:00:00       3.000000     303.070000
# 75%           2023-09-29 00:00:00       4.000000     451.500000
# max           2024-12-29 00:00:00       5.000000     599.990000
# std                           NaN       1.413548     171.840797
#
#             Discount            Tax   ShippingCost    TotalAmount  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean        0.074226      68.468902       7.406660     918.256479
# min         0.000000       0.000000       0.000000       4.270000
# 25%         0.000000      15.920000       3.680000     340.890000
# ...

# %%
df.describe(include="object")
# Out:
#            OrderID  CustomerID CustomerName ProductID    ProductName  \
# count       100000      100000       100000    100000         100000
# unique      100000       43233          200        50             50
# top     ORD0099984  CUST037103  Karan Joshi    P00019  LED Desk Lamp
# freq             1          10          556      2098           2098
#
#            Category     Brand PaymentMethod OrderStatus       City   State  \
# count        100000    100000        100000      100000     100000  100000
# unique            6        10             6           5         20      13
# top     Electronics  ReadMore   Credit Card   Delivered  Charlotte      TX
# freq          16853     10204         35038       74628       5110   24896
#
#               Country   SellerID   Month   WeekDay Weekend
# count          100000     100000  100000    100000  100000
# unique              5       1999      12         7       1
# top     United States  SELL01099  August  Thursday      No
# ...

# %%
df.sample(10)
# Out:
#           OrderID  OrderDate  CustomerID  CustomerName ProductID  \
# 46660  ORD0046661 2022-12-16  CUST014472   Sneha Verma    P00006
# 88739  ORD0088740 2022-05-06  CUST002490   Neha Kapoor    P00006
# 38984  ORD0038985 2021-01-16  CUST036950    Neha Kumar    P00024
# 57245  ORD0057246 2023-10-11  CUST014544   Vikas Verma    P00018
# 58464  ORD0058465 2022-05-24  CUST049571   Sneha Mehta    P00037
# 37402  ORD0037403 2024-01-19  CUST003821  Vihaan Singh    P00049
# 20548  ORD0020549 2021-11-14  CUST010661  Simran Reddy    P00012
# 2551   ORD0002552 2023-08-10  CUST030207   Pooja Kumar    P00010
# 81866  ORD0081867 2020-03-27  CUST028087  Pooja Kapoor    P00006
# 84554  ORD0084555 2023-03-07  CUST027196   Vikas Verma    P00008
#
#                        ProductName           Category      Brand  Quantity  \
# 46660                 Gaming Mouse        Electronics  BrightLux         1
# 88739                 Gaming Mouse  Sports & Outdoors       Apex         2
# ...

# %%
df.isnull().sum()
# Out:
# OrderID         0
# OrderDate       0
# CustomerID      0
# CustomerName    0
# ProductID       0
#                ..
# MonthNo         0
# Month           0
# Quarter         0
# WeekDay         0
# Weekend         0
# Length: 26, dtype: int64

# %%
(df.isnull().sum()/len(df))*100
# Out:
# OrderID         0.0
# OrderDate       0.0
# CustomerID      0.0
# CustomerName    0.0
# ProductID       0.0
#                ...
# MonthNo         0.0
# Month           0.0
# Quarter         0.0
# WeekDay         0.0
# Weekend         0.0
# Length: 26, dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
text_columns= df.select_dtypes(include='object').columns
for col in text_columns:
  df[col]=df[col].str.strip()

# %%
df['OrderDate']=pd.to_datetime(df['OrderDate'])

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

df.dtypes
# Out:
# OrderID                  object
# OrderDate        datetime64[ns]
# CustomerID               object
# CustomerName             object
# ProductID                object
# ProductName              object
# Category                 object
# Brand                    object
# Quantity                  int64
# UnitPrice               float64
# Discount                float64
# Tax                     float64
# ShippingCost            float64
# TotalAmount             float64
# PaymentMethod            object
# OrderStatus              object
# City                     object
# State                    object
# Country                  object
# SellerID                 object
# Year                      int32
# MonthNo                   int32
# Month                    object
# Quarter                   int32
# WeekDay                  object
# Weekend                  object
# dtype: object

# %%
nums_columns=['Quantity', 'UnitPrice', 'Discount', 'Tax', 'ShippingCost', 'TotalAmount']
for col in nums_columns:
  print(col,(df[col]<0).sum())
# Out:
# Quantity 0
# UnitPrice 0
# Discount 0
# Tax 0
# ShippingCost 0
# TotalAmount 0

# %%
for col in text_columns:
  print(col,df[col].nunique())
  print("-"*30)
# Out:
# OrderID 100000
# ------------------------------
# CustomerID 43233
# ------------------------------
# CustomerName 200
# ------------------------------
# ProductID 50
# ------------------------------
# ProductName 50
# ------------------------------
# Category 6
# ------------------------------
# Brand 10
# ------------------------------
# PaymentMethod 6
# ------------------------------
# OrderStatus 5
# ------------------------------
# City 20
# ------------------------------
# State 13
# ------------------------------
# Country 5
# ------------------------------
# SellerID 1999
# ------------------------------
# Month 12
# ------------------------------
# WeekDay 7
# ------------------------------
# Weekend 1
# ------------------------------

# %% [markdown]
# # FEATURE ENGINEERING

# %%
df['OrderDate']=pd.to_datetime(df['OrderDate'])
df['Year']=df['OrderDate'].dt.year

df['MonthNo']=df['OrderDate'].dt.month

df['Month'] = df['OrderDate'].dt.month_name()

df['Quarter']=df['OrderDate'].dt.quarter

df['WeekDay']=df['OrderDate'].dt.day_name()

# %%
df['SalesBeforeDiscount']=df['Quantity'] * df['UnitPrice']

df['DiscountAmount']=df['SalesBeforeDiscount'] * (df['Discount']/100)

df['NetSales']=df['SalesBeforeDiscount'] - df['DiscountAmount']

df['ApproxProfit']=df['NetSales']-df['ShippingCost']-df['Tax']

# %%
df.head()
# Out:
#       OrderID  OrderDate  CustomerID   CustomerName ProductID  \
# 0  ORD0000001 2023-01-31  CUST001504  Vihaan Sharma    P00014
# 1  ORD0000002 2023-12-30  CUST000178    Pooja Kumar    P00040
# 2  ORD0000003 2022-05-10  CUST047516    Sneha Singh    P00044
# 3  ORD0000004 2023-07-18  CUST030059   Vihaan Reddy    P00041
# 4  ORD0000005 2023-02-04  CUST048677  Aditya Kapoor    P00029
#
#            ProductName        Category       Brand  Quantity  UnitPrice  \
# 0           Drone Mini           Books   BrightLux         3     106.59
# 1           Microphone  Home & Kitchen  UrbanStyle         1     251.37
# 2  Power Bank 20000mAh        Clothing  UrbanStyle         3      35.03
# 3       Webcam Full HD  Home & Kitchen      Zenith         5      33.58
# 4              T-Shirt        Clothing    KiddoFun         2     515.64
#
#    Discount    Tax  ShippingCost  TotalAmount     PaymentMethod OrderStatus  \
# 0      0.00   0.00          0.09       319.86        Debit Card   Delivered
# ...

# %%
print("Total Revenue : $",round(df["TotalAmount"].sum(),2))

print("Total Orders :",df["OrderID"].nunique())

print("Total Customers :",df["CustomerID"].nunique())

print("Total Products :",df["ProductID"].nunique())

print("Total Sellers :",df["SellerID"].nunique())

print("Average Order Value : $",round(df["TotalAmount"].mean(),2))

print("Average Quantity :",round(df["Quantity"].mean(),2))

print("Average Shipping : $",round(df["ShippingCost"].mean(),2))

print("Average Discount :",round(df["Discount"].mean(),2))
# Out:
# Total Revenue : $ 91825647.92
# Total Orders : 100000
# Total Customers : 43233
# Total Products : 50
# Total Sellers : 1999
# Average Order Value : $ 918.26
# Average Quantity : 3.0
# Average Shipping : $ 7.41
# Average Discount : 0.07

# %%
df.to_csv("cleaned_amazon_orders.csv", index=False)
